# %% [markdown]
# # SaaS Product Analytics

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('../data/user_activity.csv')
sns.countplot(x='feature_used', data=df)
plt.title('Feature Usage')
plt.show()
